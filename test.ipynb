# %%
import pickle

with open("data/normal_RsideSegm_28markers.pkl","rb") as f:
    data=pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['data', 'n_trials', 'marker_names', 'subject_ids'])

# %%
type(data['data'])
# Out:
# list

# %%
len(data['data']),data['n_trials'],data['marker_names'],len(data['subject_ids'])
# Out:
# (138,
#  array([ 6, 10,  7,  7, 12,  7,  7,  8,  8,  6,  9,  5, 10,  5,  8,  6,  7,
#          5,  7,  8,  9,  9,  6,  9,  7,  9,  9,  9,  6,  6,  5, 10,  8,  6,
#          6,  8,  5,  5,  8,  8,  4,  7,  4,  8,  5,  3,  6,  5,  5,  9,  3,
#          5,  6,  4,  5,  8,  5,  4,  6,  6,  5,  6,  6,  4,  5,  7,  9,  8,
#          7,  8,  7,  6,  8,  7,  7,  6,  6,  6,  7,  3,  9,  3,  6,  8,  8,
#          6,  8,  8,  5, 13,  7,  5,  7,  8,  6,  4,  4,  7,  6,  6,  5,  4,
#          6,  5,  9,  6,  6,  5,  6,  6,  4,  6,  4,  6,  6,  8,  6,  6,  3,
#          3,  8,  3,  5,  6,  6,  6,  4,  3,  5,  9,  3,  4,  7,  6,  7,  3,
#          5,  5]),
#  ['C7',
#   'T10',
#   'CLAV',
#   'STRN',
#   'L_ASI',
#   'L_SHO',
#   'L_ELB',
#   'L_WRA',
#   'L_WRB',
#   'L_FIN',
#   'L_THI',
#   'L_KNE',
#   'L_TIB',
#   'L_ANK',
#   'L_HEE',
#   'L_TOE',
#   'R_ASI',
#   'R_SHO',
#   'R_ELB',
#   'R_WRA',
#   'R_WRB',
#   'R_FIN',
#   'R_THI',
#   'R_KNE',
#   'R_TIB',
#   'R_ANK',
#   'R_HEE',
# ...

# %%
type(data['data'][0])
# Out:
# numpy.ndarray

# %%
import numpy as np
for p_data in data["data"]:
    print(np.shape(p_data))
# Out:
# (28, 6, 1001, 3)
# (28, 10, 1001, 3)
# (28, 7, 1001, 3)
# (28, 7, 1001, 3)
# (28, 12, 1001, 3)
# (28, 7, 1001, 3)
# (28, 7, 1001, 3)
# (28, 8, 1001, 3)
# (28, 8, 1001, 3)
# (28, 6, 1001, 3)
# (28, 9, 1001, 3)
# (28, 5, 1001, 3)
# (28, 10, 1001, 3)
# (28, 5, 1001, 3)
# (28, 8, 1001, 3)
# (28, 6, 1001, 3)
# (28, 7, 1001, 3)
# (28, 5, 1001, 3)
# (28, 7, 1001, 3)
# (28, 8, 1001, 3)
# (28, 9, 1001, 3)
# (28, 9, 1001, 3)
# (28, 6, 1001, 3)
# (28, 9, 1001, 3)
# (28, 7, 1001, 3)
# (28, 9, 1001, 3)
# (28, 9, 1001, 3)
# (28, 9, 1001, 3)
# (28, 6, 1001, 3)
# (28, 6, 1001, 3)
# (28, 5, 1001, 3)
# (28, 10, 1001, 3)
# (28, 8, 1001, 3)
# (28, 6, 1001, 3)
# (28, 6, 1001, 3)
# (28, 8, 1001, 3)
# (28, 5, 1001, 3)
# (28, 5, 1001, 3)
# (28, 8, 1001, 3)
# (28, 8, 1001, 3)
# (28, 4, 1001, 3)
# (28, 7, 1001, 3)
# (28, 4, 1001, 3)
# (28, 8, 1001, 3)
# (28, 5, 1001, 3)
# (28, 3, 1001, 3)
# (28, 6, 1001, 3)
# (28, 5, 1001, 3)
# (28, 5, 1001, 3)
# (28, 9, 1001, 3)
# (28, 3, 1001, 3)
# (28, 5, 1001, 3)
# ...
